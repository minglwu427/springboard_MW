# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sheet_name = pd.read_csv('excel_sheet_names.csv')
sheet_name
# Out:
#                       Sheet_name
# 0                     Disclaimer
# 1               What's new in V3
# 2                     Front page
# 3            A1. Headline series
# 4                 TableofContent
# ..                           ...
# 98        W2. Banking Department
# 99   D1. Official Interest Rates
# 100               D2. Bilaterals
# 101             D3. ERI vintages
# 102            A3. GDP by region
#
# [103 rows x 1 columns]

# %%
#final = pd.read_excel('millenniumofdata_v3_final.xlsx')

# %%
main_df = pd.read_csv('millenniumofdata_v3_headlines.csv', index_col=0)
unit = main_df.iloc[0,:]
main_df = main_df.drop('Units', axis = 0)
main_df
# Out:
#             Real GDP of England at market prices  \
# Description
# 1209                                         NaN
# 1210                                         NaN
# 1211                                         NaN
# 1212                                         NaN
# 1213                                         NaN
# ...                                          ...
# NaN                                          NaN
# NaN                                          NaN
# NaN                                          NaN
# NaN                                          NaN
# NaN                                          NaN
#
#             Real GDP of England at factor cost   \
# Description
# 1209                                        NaN
# 1210                                        NaN
# 1211                                        NaN
# 1212                                        NaN
# 1213                                        NaN
# ...                                         ...
# ...

# %% [markdown]
# **Ok, now lets only look at Modern Era.  The time line goes back way too far doesn't really have any meaning for us**

# %%
main_df = main_df.loc['2000':'2016']
main_df = main_df.apply(lambda x :pd.to_numeric(x))
main_df.corr().round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# **Base on the result. We can see there is a lot of correlation between THE GDP with many blue including population and employment**

# %%
remove_list = [       
'Real GDP of England at factor cost ',
'Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders',
'Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders',
'Composite estimate of English and (geographically-consistent) UK real GDP at factor cost',
'Nominal UK GDP at market prices', 'Nominal UK GDP at market prices.1',
'Population (GB+NI)',
'Labour productivity.1' ,
'Notes and coin in circulation',
'UK Public sector debt.2',
'Broad Money '
]
main_df_1 = main_df.drop(remove_list, axis = 1)
main_df_1.corr().round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# ...

# %%
main_df_1.index = pd.to_datetime(main_df_1.index)
main_df_1.columns
# Out:
# Index(['Real GDP of England at market prices',
#        'Index of real UK GDP at factor cost - based on changing political boundaries, ',
#        'HP-filter of log of real composite estimate of English and UK real GDP at factor cost',
#        'Real UK gross disposable national income at market prices, constant border estimate',
#        'Real consumption', 'Real investment', 'Stockbuilding contribution',
#        'Real government consumption of goods and services', 'Export volumes',
#        'Import volumes', 'Nominal GDP of England at market prices',
#        'Population (England)', 'Employment', 'Unemployment rate',
#        'Average weekly hours worked', 'Capital Services, whole economy',
#        'TFP growth', 'Labour productivity',
#        'Labour share, whole economy excluding rents',
#        'GDP deflator at market prices', 'Export prices', 'Import prices',
#        'Terms of Trade', '$ Oil prices', 'Earnings per head',
# ...

# %%
sns.lineplot(x = main_df_1.index, y = 'House price index', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='House price index'>

# %%
sns.lineplot(x = main_df_1.index, y = 'Mortgage rates', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='Mortgage rates'>

# %% [markdown]
# **The Question is whether if it is harder to buy a house today compare to the 1990**

# %%
sns.lineplot(x = main_df_1.index, y = '$ Oil prices', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='$ Oil prices'>

# %%
sns.lineplot(x = main_df_1.index, y = 'Labour productivity', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='Labour productivity'>

# %%
sns.lineplot(x = main_df_1.index, y = 'Earnings per head', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='Earnings per head'>

# %%
sns.lineplot(x = main_df_1.index, y = 'Average weekly hours worked', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='Average weekly hours worked'>

# %%
sns.lineplot(x = main_df_1.index, y = 'Consumer price inflation', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='Consumer price inflation'>

# %%
sns.lineplot(x = main_df_1.index, y = 'Real UK gross disposable national income at market prices, constant border estimate', data=main_df_1)
# Out:
# <AxesSubplot:xlabel='Description', ylabel='Real UK gross disposable national income at market prices, constant border estimate'>
